# %% [markdown]
# <a href="https://colab.research.google.com/github/arddrasoni-commits/11_Categorical_data/blob/main/experiment_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 11
# # Title: Study of Categorical Data
# # 6 March 2026
# # Arddra Soni
# # PRN: 25070123022
# ## ENTC A1

# %%
import pandas as pd

data= {
    'Order_ID':['01','02','03','04','05','06','07','08','09','10'],

    'Category':['Electronics','Clothing','Electronics','Grocery','Clothing',
                'Electronics','Grocery','Clothing','Electronics','Grocery'],
    'Payment Method':['UPI','Card','UPI','Cash','Card',
                      'UPI','Cash','Card','UPI','Cash'],
    'Delivery_Type':['Express','Standard','Express','Standard','Express',
                     'Standard','Express','Standard','Express','Standard'],
    'Customer_Type':['New','Returning','Returning','New','Returning',
                     'New','Returning','New','Returning','New']
}
df= pd.DataFrame(data)
print(df)
# Out:
#   Order_ID     Category Payment Method Delivery_Type Customer_Type
# 0       01  Electronics            UPI       Express           New
# 1       02     Clothing           Card      Standard     Returning
# 2       03  Electronics            UPI       Express     Returning
# 3       04      Grocery           Cash      Standard           New
# 4       05     Clothing           Card       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 6       07      Grocery           Cash       Express     Returning
# 7       08     Clothing           Card      Standard           New
# 8       09  Electronics            UPI       Express     Returning
# 9       10      Grocery           Cash      Standard           New

# %%
#1. Frequency Cont
#Count how many orders in each category

print(df['Category'].value_counts())
# Out:
# Category
# Electronics    4
# Clothing       3
# Grocery        3
# Name: count, dtype: int64

# %%
print(df['Payment Method'].value_counts())
# Out:
# Payment Method
# UPI     4
# Card    3
# Cash    3
# Name: count, dtype: int64

# %%
print(df['Delivery_Type'].value_counts())
# Out:
# Delivery_Type
# Express     5
# Standard    5
# Name: count, dtype: int64

# %%
#2. Unique Values
#Display all unique categories.

print(df['Category'].unique())
# Out:
# ['Electronics' 'Clothing' 'Grocery']

# %%
print(df['Delivery_Type'].unique())
# Out:
# ['Express' 'Standard']

# %%
#3. Number of Unique Values
print(df['Category'].nunique())
# Out:
# 3

# %%
#4. Frequency of Payment Methods
print(df['Payment Method'].value_counts())
# Out:
# Payment Method
# UPI     4
# Card    3
# Cash    3
# Name: count, dtype: int64

# %%
#5. Cross Tabulation
#Category vs Payment Method
print(pd.crosstab(df['Category'],df['Payment Method']))
# Out:
# Payment Method  Card  Cash  UPI
# Category
# Clothing           3     0    0
# Electronics        0     0    4
# Grocery            0     3    0

# %%
#6. Cross Tabulation
#Delivery Type vs Customer Type
print(pd.crosstab(df['Delivery_Type'],df['Customer_Type']))
# Out:
# Customer_Type  New  Returning
# Delivery_Type
# Express          1          4
# Standard         4          1

# %%
#7. Percentage Distribution
print(df['Category'].value_counts(normalize=True)*100)
# Out:
# Category
# Electronics    40.0
# Clothing       30.0
# Grocery        30.0
# Name: proportion, dtype: float64

# %%
#8. Filtering Data
#Example: Orders from electronics category

electronics_orders= df[df['Category']=='Electronics']
print(electronics_orders)
# Out:
#   Order_ID     Category Payment Method Delivery_Type Customer_Type
# 0       01  Electronics            UPI       Express           New
# 2       03  Electronics            UPI       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 8       09  Electronics            UPI       Express     Returning

# %%
#9. Grouping
#rders by category and payment method
print(df.groupby(['Category','Payment Method']).value_counts())
# Out:
# Category     Payment Method  Order_ID  Delivery_Type  Customer_Type
# Clothing     Card            02        Standard       Returning        1
#                              05        Express        Returning        1
#                              08        Standard       New              1
# Electronics  UPI             01        Express        New              1
#                              03        Express        Returning        1
#                              06        Standard       New              1
#                              09        Express        Returning        1
# Grocery      Cash            04        Standard       New              1
#                              07        Express        Returning        1
#                              10        Standard       New              1
# Name: count, dtype: int64

# %%
#10. Sorting Data
sorted_df=df.sort_values(by='Category')
print(sorted_df)
# Out:
#   Order_ID     Category Payment Method Delivery_Type Customer_Type
# 1       02     Clothing           Card      Standard     Returning
# 4       05     Clothing           Card       Express     Returning
# 7       08     Clothing           Card      Standard           New
# 0       01  Electronics            UPI       Express           New
# 2       03  Electronics            UPI       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 8       09  Electronics            UPI       Express     Returning
# 3       04      Grocery           Cash      Standard           New
# 6       07      Grocery           Cash       Express     Returning
# 9       10      Grocery           Cash      Standard           New

# %%
df= pd.read_csv('/content/Expt11.csv')
print(df.head())
# Out:
#   Student  Gender Department Grade
# 0      S1    Male        CSE     A
# 1      S2  Female         IT     B
# 2      S3  Female        CSE     A
# 3      S4    Male        ECE     C
# 4      S5    Male         IT     B

# %%
#1. Count Student in each grade
#Find how many students obtained each grade
print(df['Grade'].value_counts())
# Out:
# Grade
# B    24
# A    22
# C    14
# Name: count, dtype: int64

# %%
#2. Percentage Distribution of Grades
print('Grade Percentage Distribution')
print(df['Grade'].value_counts(normalize=True)*100)
# Out:
# Grade Percentage Distribution
# Grade
# B    40.000000
# A    36.666667
# C    23.333333
# Name: proportion, dtype: float64

# %%
#3. Number of students in each department
print('Department Count')
print(df['Department'].value_counts())
# Out:
# Department Count
# Department
# CSE           20
# IT            18
# ECE           11
# Mechanical    11
# Name: count, dtype: int64

# %%
#4. Gender Distribution

print("Gender Count")
print(df['Gender'].value_counts())
# Out:
# Gender Count
# Gender
# Male      30
# Female    30
# Name: count, dtype: int64

# %%
#5. Gender vc Grade Analysis

print(pd.crosstab(df['Gender'],df['Grade']))
# Out:
# Grade    A   B  C
# Gender
# Female  14  11  5
# Male     8  13  9

# %%
#6. Department vs Gender

print(pd.crosstab(df['Department'],df['Gender']))
# Out:
# Gender      Female  Male
# Department
# CSE             12     8
# ECE              5     6
# IT               9     9
# Mechanical       4     7

# %%
#7. Department vs Grade Percentage

# %%
#8.Grouping Data
print(df.groupby('Department')['Grade'].value_counts())
# Out:
# Department  Grade
# CSE         A        13
#             B         4
#             C         3
# ECE         B         5
#             C         4
#             A         2
# IT          B         8
#             A         7
#             C         3
# Mechanical  B         7
#             C         4
# Name: count, dtype: int64
